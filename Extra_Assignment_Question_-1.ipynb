# %%
#print statement

print("HOPE AI")
# Out:
# HOPE AI

# %%
#Buy input

Ins_name=input("Enter your institue name: ")
print(Ins_name)
# Out:
# Enter your institue name:  HOPE AI
# HOPE AI

# %%
#Buy inputs

name=input("Enter your name: " )
age=int(input("Enter your age: "))
school=input("Enter your school name: ")
degree=input("Enter your degree: ")
# Out:
# Enter your name:  Raj
# Enter your age:  15
# Enter your school name:  Guru School
# Enter your degree:  B.E CSE

# %%
#Addition

a=43
b=34
add=a+b
print("Addition value is:",add)
# Out:
# Addition value is: 77

# %%
#Subtraction
a=43
b=34
sub=a-b
print("Subtraction value is:", sub)
# Out:
# Subtraction value is: 9

# %%
#Multiplication
a=63
b=97
mul=a*b
print("Multiplication value is:", mul)
# Out:
# Multiplication value is: 6111

# %%
#Division
a=76
b=31
div=a/b
print("Division value is:", div)
# Out:
# Division value is: 2.4516129032258065

# %%
#Floor division
a=76
b=31
floor_div=a//b
print("floor division value is:", floor_div)
# Out:
# floor division value is: 2

# %%
#Modulo
a=76
b=31
mod=a%b
print("Modulo value is:", mod)
# Out:
# Modulo value is: 14

# %%
#Power
a=4
b=4
power=a**b
print("Power value is:", power)
# Out:
# Power value is: 256
